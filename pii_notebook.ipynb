# %%
import os
import requests

# URL of the dataset
url = 'https://data.chhs.ca.gov/dataset/b79b3447-4c10-4ae6-84e2-1076f83bb24e/resource/3340c5d7-4054-4d03-90e0-5f44290ed095/download/independent-medical-review-imr-determinations-trends.csv'

# Path to the data folder and the renamed CSV file
data_folder = 'data'
csv_filename = 'original.csv'
csv_filepath = os.path.join(data_folder, csv_filename)

# Create the data folder if it doesn't exist
if not os.path.exists(data_folder):
    os.makedirs(data_folder)

# Download the CSV file and save it to the data folder
response = requests.get(url)
if response.status_code == 200:
    with open(csv_filepath, 'wb') as file:
        file.write(response.content)
    print(f"File downloaded and saved as {csv_filepath}")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# File downloaded and saved as data/original.csv

# %%
import pandas as pd

# Read the downloaded file as a pandas DataFrame
df = pd.read_csv('data/original.csv')

# Display DataFrame
df
# Out:
#       ReferenceID  ReportYear     DiagnosisCategory DiagnosisSubCategory  \
# 0      MN24-41564        2024   Endocrine/Metabolic              Obesity
# 1      EI24-41563        2024  Digestive System/ GI      Crohn's Disease
# 2      MN24-41562        2024                Cancer                Brain
# 3      MN24-41561        2024   Endocrine/Metabolic             Diabetes
# 4      MN24-41560        2024  Cardiac/Circ Problem       Varicose Veins
# ...           ...         ...                   ...                  ...
# 37611    MN01-600        2001        Morbid Obesity                Other
# 37612    MN01-596        2001  Orth/Musculoskeletal                Other
# 37613    MN01-594        2001    Infectious Disease         Lyme Disease
# 37614    EI01-592        2001                Cancer                Other
# 37615    EI01-591        2001     OB-GYN/ Pregnancy             Fibroids
#
#         TreatmentCategory TreatmentSubCategory  \
# 0                Pharmacy       Weight Control
# 1      Diag Imag & Screen             Lab Work
# 2             Cancer Care                Other
# 3                Pharmacy       Weight Control
# 4        Cardio-Vasc Proc        Vein Ablation
# ...                   ...                  ...
# 37611       Gen Surg Proc       Gastric Bypass
# 37612  Diag Imag & Screen                  MRI
# 37613            Pharmacy          Antibiotics
# 37614         Cancer Care       Clin Trial (I)
# 37615         Ob-Gyn Proc     Uter Art Emboliz
#
#                             Determination                          Type  \
# 0      Overturned Decision of Health Plan             Medical Necessity
# 1      Overturned Decision of Health Plan  Experimental/Investigational
# 2      Overturned Decision of Health Plan             Medical Necessity
# 3      Overturned Decision of Health Plan             Medical Necessity
# 4          Upheld Decision of Health Plan             Medical Necessity
# ...                                   ...                           ...
# 37611      Upheld Decision of Health Plan             Medical Necessity
# 37612      Upheld Decision of Health Plan             Medical Necessity
# 37613      Upheld Decision of Health Plan             Medical Necessity
# 37614      Upheld Decision of Health Plan  Experimental/Investigational
# 37615      Upheld Decision of Health Plan  Experimental/Investigational
#
#        AgeRange PatientGender    IMRType  DaysToReview  DaysToAdopt  \
# 0      31 to 40        Female   Standard          19.0           41
# 1      51 to 64        Female   Standard          21.0           45
# 2      41 to 50          Male   Standard          21.0           47
# 3      51 to 64        Female  Expedited           2.0           10
# 4      51 to 64          Male  Expedited           2.0           11
# ...         ...           ...        ...           ...          ...
# 37611       NaN           NaN   Standard          18.0           44
# 37612       NaN           NaN   Standard          21.0           44
# 37613       NaN           NaN  Expedited           0.0           15
# 37614       NaN           NaN  Expedited           7.0           14
# 37615       NaN           NaN  Expedited           7.0           21
#
#                                                 Findings
# 0      Nature of Statutory Criteria/Case Summary: The...
# 1      Findings:  The physician reviewer found that N...
# 2      Findings:  The physician reviewer found that N...
# 3      Nature of Statutory Criteria/Case Summary: A p...
# 4      Nature of Statutory Criteria/Case Summary: The...
# ...                                                  ...
# 37611  A 34-year-old female requested authorization a...
# 37612  A 64-year-old female enrollee requested author...
# 37613  A 33-year-old female enrollee requested author...
# 37614  A 55-year-old male enrollee requested authoriz...
# 37615  A 51-year-old female enrollee requested author...
#
# [37616 rows x 14 columns]

# %%
df = df.drop(columns=['IMRType', 'DaysToReview', 'DaysToAdopt'])
df
# Out:
#       ReferenceID  ReportYear     DiagnosisCategory DiagnosisSubCategory  \
# 0      MN24-41564        2024   Endocrine/Metabolic              Obesity
# 1      EI24-41563        2024  Digestive System/ GI      Crohn's Disease
# 2      MN24-41562        2024                Cancer                Brain
# 3      MN24-41561        2024   Endocrine/Metabolic             Diabetes
# 4      MN24-41560        2024  Cardiac/Circ Problem       Varicose Veins
# ...           ...         ...                   ...                  ...
# 37611    MN01-600        2001        Morbid Obesity                Other
# 37612    MN01-596        2001  Orth/Musculoskeletal                Other
# 37613    MN01-594        2001    Infectious Disease         Lyme Disease
# 37614    EI01-592        2001                Cancer                Other
# 37615    EI01-591        2001     OB-GYN/ Pregnancy             Fibroids
#
#         TreatmentCategory TreatmentSubCategory  \
# 0                Pharmacy       Weight Control
# 1      Diag Imag & Screen             Lab Work
# 2             Cancer Care                Other
# 3                Pharmacy       Weight Control
# 4        Cardio-Vasc Proc        Vein Ablation
# ...                   ...                  ...
# 37611       Gen Surg Proc       Gastric Bypass
# 37612  Diag Imag & Screen                  MRI
# 37613            Pharmacy          Antibiotics
# 37614         Cancer Care       Clin Trial (I)
# 37615         Ob-Gyn Proc     Uter Art Emboliz
#
#                             Determination                          Type  \
# 0      Overturned Decision of Health Plan             Medical Necessity
# 1      Overturned Decision of Health Plan  Experimental/Investigational
# 2      Overturned Decision of Health Plan             Medical Necessity
# 3      Overturned Decision of Health Plan             Medical Necessity
# 4          Upheld Decision of Health Plan             Medical Necessity
# ...                                   ...                           ...
# 37611      Upheld Decision of Health Plan             Medical Necessity
# 37612      Upheld Decision of Health Plan             Medical Necessity
# 37613      Upheld Decision of Health Plan             Medical Necessity
# 37614      Upheld Decision of Health Plan  Experimental/Investigational
# 37615      Upheld Decision of Health Plan  Experimental/Investigational
#
#        AgeRange PatientGender  \
# 0      31 to 40        Female
# 1      51 to 64        Female
# 2      41 to 50          Male
# 3      51 to 64        Female
# 4      51 to 64          Male
# ...         ...           ...
# 37611       NaN           NaN
# 37612       NaN           NaN
# 37613       NaN           NaN
# 37614       NaN           NaN
# 37615       NaN           NaN
#
#                                                 Findings
# 0      Nature of Statutory Criteria/Case Summary: The...
# 1      Findings:  The physician reviewer found that N...
# 2      Findings:  The physician reviewer found that N...
# 3      Nature of Statutory Criteria/Case Summary: A p...
# 4      Nature of Statutory Criteria/Case Summary: The...
# ...                                                  ...
# 37611  A 34-year-old female requested authorization a...
# 37612  A 64-year-old female enrollee requested author...
# 37613  A 33-year-old female enrollee requested author...
# 37614  A 55-year-old male enrollee requested authoriz...
# 37615  A 51-year-old female enrollee requested author...
#
# [37616 rows x 11 columns]

# %%
from faker import Faker
import random

# Instantiate Faker
fake = Faker(locale='en_US')
fake.seed_instance(1234)

# %%
df['AgeRange'].unique()
# Out:
# array(['31 to 40', '51 to 64', '41 to 50', '65+', '0 to 10', '21 to 30',
#        '11 to 20', nan], dtype=object)

# %%
def fake_name(gender: str):
    if gender == 'Male':
        return fake.name_male()
    elif gender == 'Female':
        return fake.name_female()
    else:
        return fake.name()
    
def fake_age_within_range(age_range):
    if age_range == '0 to 10':
        return random.randint(0, 10)
    elif age_range == '11 to 20':
        return random.randint(11, 20)
    elif age_range == '21 to 30':
        return random.randint(21, 30)
    elif age_range == '31 to 40':
        return random.randint(31, 40)
    elif age_range == '41 to 50':
        return random.randint(41, 50)
    elif age_range == '51 to 64':
        return random.randint(51, 64)
    elif age_range == '65+':
        return random.randint(65, 100)  # Assuming maximum age of 100 for the example
    else:
        return None

def fake_blood_type():
    real_blood_types = ['A+', 'A-', 'B+', 'B-', 'O+', 'O-', 'AB+', 'AB-']
    
    # Randomly select and return a blood type
    return random.choice(real_blood_types)

def fake_insurance_provider():
    insurance_providers = [
        "UnitedHealth Group",
        "Kaiser Foundation",
        "Anthem Inc.",
        "Centene Corporation",
        "Humana",
        "CVS Health (Aetna)",
        "HCSC (Health Care Service Corporation)",
        "Cigna Health",
        "Molina Healthcare",
        "Independence Health Group",
        "GuideWell Mutual Holding",
        "WellCare",
        "Blue Cross Blue Shield",
        "Highmark",
        "Medicare",
        "Medicaid",
    ]

    return random.choice(insurance_providers)

def fake_consulting_physicians():
    consulting_physicians = ['Dr. Alexandria Gaines', 'Dr. Eddie Young', 'Dr. James Barber', 'Dr. Jerry Daniels', 'Dr. Michelle Lamb', 'Dr. Shelly Hunt']
    return random.choice(consulting_physicians)

# %%
# Add columns with fake data

df['PatientName'] = df['PatientGender'].apply(fake_name)
df['PatientAge'] = df['AgeRange'].apply(fake_age_within_range)
df['PatientPhone'] = df.apply(lambda _: fake.bothify(text='+1-###-###-####'), axis=1)
df['PatientAddress'] = df.apply(lambda _: fake.address(), axis=1)
df['PatientBloodType'] = df.apply(lambda _: fake_blood_type(), axis=1)
df['PatientSSN'] = df.apply(lambda _: fake.ssn(), axis=1)
df['PatientInsuranceProvider'] = df.apply(lambda _: fake_insurance_provider(), axis=1)
df['PatientInsuranceNumber'] = df.apply(lambda _: fake.bothify(text='?#??##?#?##?', letters='ABCDEFGHIJKLMNOPQRSTUVWXYZ'), axis=1)
df['ConsultingPhysician'] = df.apply(lambda _: fake_consulting_physicians(), axis=1)

# %%
df
# Out:
#       ReferenceID  ReportYear     DiagnosisCategory DiagnosisSubCategory  \
# 0      MN24-41564        2024   Endocrine/Metabolic              Obesity
# 1      EI24-41563        2024  Digestive System/ GI      Crohn's Disease
# 2      MN24-41562        2024                Cancer                Brain
# 3      MN24-41561        2024   Endocrine/Metabolic             Diabetes
# 4      MN24-41560        2024  Cardiac/Circ Problem       Varicose Veins
# ...           ...         ...                   ...                  ...
# 37611    MN01-600        2001        Morbid Obesity                Other
# 37612    MN01-596        2001  Orth/Musculoskeletal                Other
# 37613    MN01-594        2001    Infectious Disease         Lyme Disease
# 37614    EI01-592        2001                Cancer                Other
# 37615    EI01-591        2001     OB-GYN/ Pregnancy             Fibroids
#
#         TreatmentCategory TreatmentSubCategory  \
# 0                Pharmacy       Weight Control
# 1      Diag Imag & Screen             Lab Work
# 2             Cancer Care                Other
# 3                Pharmacy       Weight Control
# 4        Cardio-Vasc Proc        Vein Ablation
# ...                   ...                  ...
# 37611       Gen Surg Proc       Gastric Bypass
# 37612  Diag Imag & Screen                  MRI
# 37613            Pharmacy          Antibiotics
# 37614         Cancer Care       Clin Trial (I)
# 37615         Ob-Gyn Proc     Uter Art Emboliz
#
#                             Determination                          Type  \
# 0      Overturned Decision of Health Plan             Medical Necessity
# 1      Overturned Decision of Health Plan  Experimental/Investigational
# 2      Overturned Decision of Health Plan             Medical Necessity
# 3      Overturned Decision of Health Plan             Medical Necessity
# 4          Upheld Decision of Health Plan             Medical Necessity
# ...                                   ...                           ...
# 37611      Upheld Decision of Health Plan             Medical Necessity
# 37612      Upheld Decision of Health Plan             Medical Necessity
# 37613      Upheld Decision of Health Plan             Medical Necessity
# 37614      Upheld Decision of Health Plan  Experimental/Investigational
# 37615      Upheld Decision of Health Plan  Experimental/Investigational
#
#        AgeRange PatientGender  ...        Patient Name       PatientName  \
# 0      31 to 40        Female  ...     Elizabeth Noble  Crystal Martinez
# 1      51 to 64        Female  ...  Kristen Strickland        Amanda Day
# 2      41 to 50          Male  ...      Andrew Collins     Jeffrey Perez
# 3      51 to 64        Female  ...  Rebecca Livingston     Nancy Stanley
# 4      51 to 64          Male  ...   Mr. Kevin Fry III      Tyler Garcia
# ...         ...           ...  ...                 ...               ...
# 37611       NaN           NaN  ...       Tiffany Perez       Tara Porter
# 37612       NaN           NaN  ...            John Fox   Anthony Francis
# 37613       NaN           NaN  ...       Bernard Davis       Brian Eaton
# 37614       NaN           NaN  ...  Zachary Washington   Anthony Frazier
# 37615       NaN           NaN  ...       Suzanne Stone    Jeffrey Bender
#
#       PatientAge     PatientPhone  \
# 0           36.0  +1-166-960-3913
# 1           53.0  +1-056-684-8598
# 2           50.0  +1-063-357-3002
# 3           63.0  +1-668-024-2510
# 4           59.0  +1-526-104-6354
# ...          ...              ...
# 37611        NaN  +1-961-408-3567
# 37612        NaN  +1-756-265-3367
# 37613        NaN  +1-606-053-5170
# 37614        NaN  +1-136-935-3559
# 37615        NaN  +1-442-709-1193
#
#                                           PatientAddress PatientBloodType  \
# 0       840 Hughes Groves Suite 158\nDavisview, ND 68983               A+
# 1       009 Smith Knoll Apt. 821\nJessicashire, NH 46684               O-
# 2      6851 Koch Throughway Apt. 028\nPort Loritown, ...               B+
# 3      290 Shannon Place Apt. 555\nNew Jessica, AZ 26582               B-
# 4                       PSC 4648, Box 1316\nAPO AE 63044               B+
# ...                                                  ...              ...
# 37611          49050 Ward Locks\nEast Johnview, MS 07059               B-
# 37612  782 Ramsey Unions Suite 632\nLake Amandamouth,...               B+
# 37613            4335 Stone Ferry\nRichardfurt, PA 93575               O-
# 37614            389 Troy Walks\nNorth Matthew, OH 16909               B+
# 37615        51593 Trujillo Flats\nReevesburgh, VA 51320              AB+
#
#         PatientSSN   PatientInsuranceProvider PatientInsuranceNumber  \
# 0      530-81-8637         UnitedHealth Group           Q2VO96L0V64O
# 1      273-49-1265                   WellCare           F4MT51M7Y80U
# 2      895-06-2641  Independence Health Group           M9NS19N0C66G
# 3      071-34-8878               Cigna Health           I7OJ75H7P63V
# 4      505-82-0876                   Medicaid           N9UU51K7E56H
# ...            ...                        ...                    ...
# 37611  094-61-6250                   Medicaid           D2LM00M5C30Y
# 37612  700-29-0666               Cigna Health           C5KT83Y8M71G
# 37613  873-37-1814                   Medicare           T2KU96L6C56H
# 37614  093-78-0112         UnitedHealth Group           G1OM14A1N45N
# 37615  753-77-5776  Independence Health Group           O7TJ98U7W34B
#
#          ConsultingPhysician
# 0          Dr. Jerry Daniels
# 1          Dr. Michelle Lamb
# 2            Dr. Eddie Young
# 3           Dr. James Barber
# 4            Dr. Shelly Hunt
# ...                      ...
# 37611      Dr. Michelle Lamb
# 37612  Dr. Alexandria Gaines
# 37613      Dr. Jerry Daniels
# 37614       Dr. James Barber
# 37615        Dr. Shelly Hunt
#
# [37616 rows x 21 columns]

# %%
df.to_csv('data/pii.csv', index=False)
